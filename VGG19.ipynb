# %%
####################  Deep Learning Script for Bainite - Martensite Classification       ########################

####################  Written by Juancheng Li, Modified by Xiaohan Bie 2022-07-04       ########################
import os
import cv2
import matplotlib.pyplot as plt
import numpy as np
import PIL
from PIL import Image

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras import layers

from google.colab import drive
drive.mount('/content/drive')

# folder path
base_dir = '/content/drive/My Drive/SURE Summer 2022/'
train_dir = os.path.join(base_dir, 'train2')
validation_dir = os.path.join(base_dir, 'validation2')
test_dir = os.path.join(base_dir, 'test2')
# Out:
# Mounted at /content/drive

# %%
# setting parameters
initial_epochs=40
fine_tune_epochs = 30

# %%
# load image dataset
training_set = image_dataset_from_directory(train_dir,
                                             shuffle=True,
                                             batch_size=32,
                                             image_size=(224, 224))
validation_set = image_dataset_from_directory(validation_dir,
                                                  shuffle=True,
                                                  batch_size=32,
                                                  image_size=(224, 224))
# load image dataset
test_set = image_dataset_from_directory(test_dir,
                                             shuffle=False,
                                             batch_size=32,
                                             image_size=(224, 224))
# Out:
# Found 2140 files belonging to 2 classes.
# Found 536 files belonging to 2 classes.
# Found 180 files belonging to 2 classes.

# %%
# data augmentation (add preprocessing layers to model)
data_augmentation = tf.keras.Sequential([
  layers.RandomRotation(0.2),
  layers.RandomFlip("horizontal_and_vertical"),
])

# %%
# define based model = VGG19
# define input shape as 224 x 224 x 3
# dataset trained on is imagenet
preprocess_input = tf.keras.applications.vgg19.preprocess_input
base_model = keras.applications.vgg19.VGG19(
    weights='imagenet',
    input_shape=(224, 224, 3),
    include_top=False)  # discard FC layer from VGG19  model
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step

# %%
# freeze base model layers
base_model.trainable = False

# define input sizes to deep learning model
inputs = keras.Input(shape=(224, 224, 3))

# augment data
x = data_augmentation(inputs)

preprocess_input = tf.keras.applications.xception.preprocess_input
# preprocess input values scale to (-1,1) to fit Xception  model
x = preprocess_input(x)

# build FC layer with our image dataset x
x = base_model(x, training=False)
x = keras.layers.GlobalAveragePooling2D()(x)
x = keras.layers.Dropout(0.2)(x)
outputs = keras.layers.Dense(1, activation = 'sigmoid')(x)
model = keras.Model(inputs, outputs)

# %%
# compile model and train
initial_epochs=40
model.compile(optimizer='adam', loss=tf.keras.losses.BinaryCrossentropy(),metrics=[keras.metrics.BinaryAccuracy(), tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tf.keras.metrics.AUC()])
history = model.fit(training_set, epochs=initial_epochs, validation_data=validation_set)
# Out:
# Epoch 1/40
# 67/67 [==============================] - 427s 6s/step - loss: 0.6692 - binary_accuracy: 0.5949 - precision: 0.6009 - recall: 0.7861 - auc: 0.6148 - val_loss: 0.6278 - val_binary_accuracy: 0.7201 - val_precision: 0.6764 - val_recall: 0.9424 - val_auc: 0.7972
# Epoch 2/40
# 67/67 [==============================] - 16s 225ms/step - loss: 0.6178 - binary_accuracy: 0.6729 - precision: 0.6591 - recall: 0.8404 - auc: 0.7352 - val_loss: 0.5889 - val_binary_accuracy: 0.7593 - val_precision: 0.7255 - val_recall: 0.9051 - val_auc: 0.8290
# Epoch 3/40
# 67/67 [==============================] - 16s 230ms/step - loss: 0.5867 - binary_accuracy: 0.7243 - precision: 0.7118 - recall: 0.8387 - auc: 0.7894 - val_loss: 0.5620 - val_binary_accuracy: 0.7705 - val_precision: 0.7722 - val_recall: 0.8271 - val_auc: 0.8403
# Epoch 4/40
# 67/67 [==============================] - 16s 236ms/step - loss: 0.5647 - binary_accuracy: 0.7346 - precision: 0.7230 - recall: 0.8396 - auc: 0.8015 - val_loss: 0.5426 - val_binary_accuracy: 0.7761 - val_precision: 0.7907 - val_recall: 0.8068 - val_auc: 0.8478
# Epoch 5/40
# 67/67 [==============================] - 16s 234ms/step - loss: 0.5499 - binary_accuracy: 0.7364 - precision: 0.7298 - recall: 0.8277 - auc: 0.8120 - val_loss: 0.5244 - val_binary_accuracy: 0.7910 - val_precision: 0.7781 - val_recall: 0.8678 - val_auc: 0.8539
# Epoch 6/40
# 67/67 [==============================] - 16s 228ms/step - loss: 0.5365 - binary_accuracy: 0.7425 - precision: 0.7388 - recall: 0.8234 - auc: 0.8213 - val_loss: 0.5120 - val_binary_accuracy: 0.7966 - val_precision: 0.7835 - val_recall: 0.8712 - val_auc: 0.8594
# Epoch 7/40
# 67/67 [==============================] - 17s 246ms/step - loss: 0.5174 - binary_accuracy: 0.7542 - precision: 0.7470 - recall: 0.8370 - auc: 0.8370 - val_loss: 0.5034 - val_binary_accuracy: 0.7966 - val_precision: 0.8059 - val_recall: 0.8305 - val_auc: 0.8632
# Epoch 8/40
# 67/67 [==============================] - 16s 229ms/step - loss: 0.5182 - binary_accuracy: 0.7500 - precision: 0.7522 - recall: 0.8141 - auc: 0.8307 - val_loss: 0.4934 - val_binary_accuracy: 0.7966 - val_precision: 0.8019 - val_recall: 0.8373 - val_auc: 0.8672
# Epoch 9/40
# 67/67 [==============================] - 16s 232ms/step - loss: 0.5136 - binary_accuracy: 0.7547 - precision: 0.7517 - recall: 0.8277 - auc: 0.8338 - val_loss: 0.4847 - val_binary_accuracy: 0.8078 - val_precision: 0.8019 - val_recall: 0.8644 - val_auc: 0.8704
# Epoch 10/40
# 67/67 [==============================] - 16s 226ms/step - loss: 0.5008 - binary_accuracy: 0.7533 - precision: 0.7592 - recall: 0.8081 - auc: 0.8442 - val_loss: 0.4791 - val_binary_accuracy: 0.8060 - val_precision: 0.8152 - val_recall: 0.8373 - val_auc: 0.8744
# Epoch 11/40
# 67/67 [==============================] - 16s 231ms/step - loss: 0.4947 - binary_accuracy: 0.7734 - precision: 0.7757 - recall: 0.8277 - auc: 0.8468 - val_loss: 0.4714 - val_binary_accuracy: 0.8116 - val_precision: 0.8109 - val_recall: 0.8576 - val_auc: 0.8773
# Epoch 12/40
# 67/67 [==============================] - 16s 229ms/step - loss: 0.4958 - binary_accuracy: 0.7664 - precision: 0.7686 - recall: 0.8234 - auc: 0.8439 - val_loss: 0.4669 - val_binary_accuracy: 0.8097 - val_precision: 0.8185 - val_recall: 0.8407 - val_auc: 0.8801
# Epoch 13/40
# 67/67 [==============================] - 16s 228ms/step - loss: 0.4816 - binary_accuracy: 0.7706 - precision: 0.7715 - recall: 0.8285 - auc: 0.8573 - val_loss: 0.4639 - val_binary_accuracy: 0.8022 - val_precision: 0.8225 - val_recall: 0.8169 - val_auc: 0.8829
# Epoch 14/40
# 67/67 [==============================] - 16s 228ms/step - loss: 0.4867 - binary_accuracy: 0.7720 - precision: 0.7842 - recall: 0.8081 - auc: 0.8494 - val_loss: 0.4566 - val_binary_accuracy: 0.8153 - val_precision: 0.8224 - val_recall: 0.8475 - val_auc: 0.8860
# Epoch 15/40
# 67/67 [==============================] - 16s 229ms/step - loss: 0.4792 - binary_accuracy: 0.7715 - precision: 0.7763 - recall: 0.8217 - auc: 0.8558 - val_loss: 0.4511 - val_binary_accuracy: 0.8134 - val_precision: 0.8155 - val_recall: 0.8542 - val_auc: 0.8891
# Epoch 16/40
# 67/67 [==============================] - 16s 230ms/step - loss: 0.4809 - binary_accuracy: 0.7780 - precision: 0.7819 - recall: 0.8277 - auc: 0.8541 - val_loss: 0.4475 - val_binary_accuracy: 0.8153 - val_precision: 0.8203 - val_recall: 0.8508 - val_auc: 0.8913
# Epoch 17/40
# 67/67 [==============================] - 16s 230ms/step - loss: 0.4715 - binary_accuracy: 0.7832 - precision: 0.7907 - recall: 0.8243 - auc: 0.8620 - val_loss: 0.4445 - val_binary_accuracy: 0.8134 - val_precision: 0.8239 - val_recall: 0.8407 - val_auc: 0.8939
# Epoch 18/40
# 67/67 [==============================] - 16s 229ms/step - loss: 0.4667 - binary_accuracy: 0.7841 - precision: 0.7939 - recall: 0.8209 - auc: 0.8656 - val_loss: 0.4437 - val_binary_accuracy: 0.8153 - val_precision: 0.8379 - val_recall: 0.8237 - val_auc: 0.8962
# Epoch 19/40
# 67/67 [==============================] - 16s 224ms/step - loss: 0.4664 - binary_accuracy: 0.7911 - precision: 0.7960 - recall: 0.8345 - auc: 0.8656 - val_loss: 0.4364 - val_binary_accuracy: 0.8153 - val_precision: 0.8267 - val_recall: 0.8407 - val_auc: 0.8984
# Epoch 20/40
# 67/67 [==============================] - 16s 233ms/step - loss: 0.4668 - binary_accuracy: 0.7804 - precision: 0.7897 - recall: 0.8192 - auc: 0.8648 - val_loss: 0.4335 - val_binary_accuracy: 0.8190 - val_precision: 0.8322 - val_recall: 0.8407 - val_auc: 0.9008
# Epoch 21/40
# 67/67 [==============================] - 16s 231ms/step - loss: 0.4627 - binary_accuracy: 0.7874 - precision: 0.7867 - recall: 0.8421 - auc: 0.8679 - val_loss: 0.4336 - val_binary_accuracy: 0.8209 - val_precision: 0.8419 - val_recall: 0.8305 - val_auc: 0.9032
# Epoch 22/40
# 67/67 [==============================] - 16s 230ms/step - loss: 0.4606 - binary_accuracy: 0.7832 - precision: 0.7912 - recall: 0.8234 - auc: 0.8694 - val_loss: 0.4266 - val_binary_accuracy: 0.8190 - val_precision: 0.8345 - val_recall: 0.8373 - val_auc: 0.9053
# Epoch 23/40
# 67/67 [==============================] - 16s 228ms/step - loss: 0.4521 - binary_accuracy: 0.7916 - precision: 0.7985 - recall: 0.8311 - auc: 0.8746 - val_loss: 0.4257 - val_binary_accuracy: 0.8190 - val_precision: 0.8367 - val_recall: 0.8339 - val_auc: 0.9068
# Epoch 24/40
# 67/67 [==============================] - 16s 230ms/step - loss: 0.4477 - binary_accuracy: 0.8005 - precision: 0.8080 - recall: 0.8362 - auc: 0.8769 - val_loss: 0.4185 - val_binary_accuracy: 0.8358 - val_precision: 0.8307 - val_recall: 0.8814 - val_auc: 0.9085
# Epoch 25/40
# 67/67 [==============================] - 16s 230ms/step - loss: 0.4618 - binary_accuracy: 0.7771 - precision: 0.7815 - recall: 0.8260 - auc: 0.8661 - val_loss: 0.4166 - val_binary_accuracy: 0.8302 - val_precision: 0.8355 - val_recall: 0.8610 - val_auc: 0.9098
# Epoch 26/40
# 67/67 [==============================] - 16s 223ms/step - loss: 0.4457 - binary_accuracy: 0.7925 - precision: 0.7989 - recall: 0.8328 - auc: 0.8791 - val_loss: 0.4140 - val_binary_accuracy: 0.8302 - val_precision: 0.8377 - val_recall: 0.8576 - val_auc: 0.9108
# Epoch 27/40
# 67/67 [==============================] - 16s 230ms/step - loss: 0.4363 - binary_accuracy: 0.7967 - precision: 0.8088 - recall: 0.8260 - auc: 0.8860 - val_loss: 0.4174 - val_binary_accuracy: 0.8190 - val_precision: 0.8438 - val_recall: 0.8237 - val_auc: 0.9130
# Epoch 28/40
# 67/67 [==============================] - 16s 232ms/step - loss: 0.4458 - binary_accuracy: 0.7930 - precision: 0.8025 - recall: 0.8277 - auc: 0.8785 - val_loss: 0.4106 - val_binary_accuracy: 0.8265 - val_precision: 0.8435 - val_recall: 0.8407 - val_auc: 0.9141
# Epoch 29/40
# 67/67 [==============================] - 16s 229ms/step - loss: 0.4383 - binary_accuracy: 0.8009 - precision: 0.8057 - recall: 0.8413 - auc: 0.8831 - val_loss: 0.4137 - val_binary_accuracy: 0.8190 - val_precision: 0.8486 - val_recall: 0.8169 - val_auc: 0.9155
# Epoch 30/40
# 67/67 [==============================] - 16s 228ms/step - loss: 0.4430 - binary_accuracy: 0.7958 - precision: 0.8090 - recall: 0.8234 - auc: 0.8790 - val_loss: 0.4027 - val_binary_accuracy: 0.8358 - val_precision: 0.8439 - val_recall: 0.8610 - val_auc: 0.9168
# Epoch 31/40
# 67/67 [==============================] - 16s 227ms/step - loss: 0.4309 - binary_accuracy: 0.8056 - precision: 0.8083 - recall: 0.8480 - auc: 0.8890 - val_loss: 0.4031 - val_binary_accuracy: 0.8265 - val_precision: 0.8459 - val_recall: 0.8373 - val_auc: 0.9184
# Epoch 32/40
# 67/67 [==============================] - 16s 228ms/step - loss: 0.4338 - binary_accuracy: 0.8047 - precision: 0.8100 - recall: 0.8430 - auc: 0.8868 - val_loss: 0.4039 - val_binary_accuracy: 0.8265 - val_precision: 0.8483 - val_recall: 0.8339 - val_auc: 0.9193
# Epoch 33/40
# 67/67 [==============================] - 16s 230ms/step - loss: 0.4283 - binary_accuracy: 0.8075 - precision: 0.8104 - recall: 0.8489 - auc: 0.8900 - val_loss: 0.3977 - val_binary_accuracy: 0.8321 - val_precision: 0.8451 - val_recall: 0.8508 - val_auc: 0.9212
# Epoch 34/40
# 67/67 [==============================] - 16s 225ms/step - loss: 0.4305 - binary_accuracy: 0.8145 - precision: 0.8167 - recall: 0.8548 - auc: 0.8879 - val_loss: 0.4057 - val_binary_accuracy: 0.8209 - val_precision: 0.8699 - val_recall: 0.7932 - val_auc: 0.9223
# Epoch 35/40
# 67/67 [==============================] - 16s 226ms/step - loss: 0.4352 - binary_accuracy: 0.8009 - precision: 0.8067 - recall: 0.8396 - auc: 0.8842 - val_loss: 0.4001 - val_binary_accuracy: 0.8302 - val_precision: 0.8617 - val_recall: 0.8237 - val_auc: 0.9234
# Epoch 36/40
# 67/67 [==============================] - 16s 228ms/step - loss: 0.4256 - binary_accuracy: 0.8117 - precision: 0.8200 - recall: 0.8430 - auc: 0.8922 - val_loss: 0.3919 - val_binary_accuracy: 0.8377 - val_precision: 0.8514 - val_recall: 0.8542 - val_auc: 0.9244
# Epoch 37/40
# 67/67 [==============================] - 16s 222ms/step - loss: 0.4277 - binary_accuracy: 0.8061 - precision: 0.8130 - recall: 0.8413 - auc: 0.8891 - val_loss: 0.3929 - val_binary_accuracy: 0.8358 - val_precision: 0.8581 - val_recall: 0.8407 - val_auc: 0.9253
# Epoch 38/40
# 67/67 [==============================] - 16s 229ms/step - loss: 0.4330 - binary_accuracy: 0.8117 - precision: 0.8210 - recall: 0.8413 - auc: 0.8870 - val_loss: 0.3923 - val_binary_accuracy: 0.8358 - val_precision: 0.8632 - val_recall: 0.8339 - val_auc: 0.9264
# Epoch 39/40
# 67/67 [==============================] - 16s 231ms/step - loss: 0.4257 - binary_accuracy: 0.8075 - precision: 0.8181 - recall: 0.8362 - auc: 0.8898 - val_loss: 0.3892 - val_binary_accuracy: 0.8358 - val_precision: 0.8581 - val_recall: 0.8407 - val_auc: 0.9274
# Epoch 40/40
# 67/67 [==============================] - 16s 229ms/step - loss: 0.4266 - binary_accuracy: 0.8028 - precision: 0.8088 - recall: 0.8404 - auc: 0.8900 - val_loss: 0.3881 - val_binary_accuracy: 0.8396 - val_precision: 0.8641 - val_recall: 0.8407 - val_auc: 0.9281

# %%
# list all data in history
print(history.history.keys())
# summarize history for accuracy
# Out:
# dict_keys(['loss', 'binary_accuracy', 'precision', 'recall', 'auc', 'val_loss', 'val_binary_accuracy', 'val_precision', 'val_recall', 'val_auc'])

# %%
##################################################
acc = history.history['binary_accuracy']
val_acc = history.history['val_binary_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))


plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend()
plt.show()


plt.figure(figsize=(8, 8))
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()
plt.show()
##################################################

# %%
test = model.evaluate(test_set)
print('test set loss:' + str(test[0]))
print('test set accuracy:' + str(test[1]))
# Out:
# 6/6 [==============================] - 20s 3s/step - loss: 0.3225 - binary_accuracy: 0.8833 - precision: 0.8529 - recall: 0.9355 - auc: 0.9747
# test set loss:0.3225420117378235
# test set accuracy:0.8833333253860474

# %%
base_model = model.layers[4]
base_model.trainable = True

print("Number of layers in the base model: ", len(base_model.layers))

fine_tune_at = 16
base_learning_rate = 0.001
total_epochs =  initial_epochs + fine_tune_epochs

for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False

loss_function=tf.keras.losses.BinaryCrossentropy()

optimizer = tf.keras.optimizers.Adam(learning_rate=0.1*base_learning_rate)

metrics=[keras.metrics.BinaryAccuracy(), tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tf.keras.metrics.AUC()]
model.compile(loss=loss_function,
              optimizer = optimizer,
              metrics=metrics)

history_fine = model.fit(training_set,
                         epochs=total_epochs,
                         initial_epoch=history.epoch[-1],
                         validation_data=validation_set,
                         )
# Out:
# Number of layers in the base model:  22
# Epoch 40/70
# 67/67 [==============================] - 24s 301ms/step - loss: 0.4964 - binary_accuracy: 0.7911 - precision_1: 0.8043 - recall_1: 0.8200 - auc_1: 0.8617 - val_loss: 0.3134 - val_binary_accuracy: 0.8246 - val_precision_1: 0.9902 - val_recall_1: 0.6881 - val_auc_1: 0.9926
# Epoch 41/70
# 67/67 [==============================] - 21s 300ms/step - loss: 0.2138 - binary_accuracy: 0.9154 - precision_1: 0.9272 - recall_1: 0.9185 - auc_1: 0.9733 - val_loss: 0.1999 - val_binary_accuracy: 0.9011 - val_precision_1: 0.9919 - val_recall_1: 0.8271 - val_auc_1: 0.9942
# Epoch 42/70
# 67/67 [==============================] - 20s 287ms/step - loss: 0.1306 - binary_accuracy: 0.9509 - precision_1: 0.9566 - recall_1: 0.9542 - auc_1: 0.9896 - val_loss: 0.6645 - val_binary_accuracy: 0.7071 - val_precision_1: 1.0000 - val_recall_1: 0.4678 - val_auc_1: 0.9954
# Epoch 43/70
# 67/67 [==============================] - 21s 300ms/step - loss: 0.1437 - binary_accuracy: 0.9458 - precision_1: 0.9470 - recall_1: 0.9550 - auc_1: 0.9872 - val_loss: 1.5031 - val_binary_accuracy: 0.5653 - val_precision_1: 1.0000 - val_recall_1: 0.2102 - val_auc_1: 0.9223
# Epoch 44/70
# 67/67 [==============================] - 19s 282ms/step - loss: 0.1170 - binary_accuracy: 0.9589 - precision_1: 0.9642 - recall_1: 0.9610 - auc_1: 0.9908 - val_loss: 0.1644 - val_binary_accuracy: 0.9403 - val_precision_1: 0.9962 - val_recall_1: 0.8949 - val_auc_1: 0.9941
# Epoch 45/70
# 67/67 [==============================] - 20s 291ms/step - loss: 0.0804 - binary_accuracy: 0.9668 - precision_1: 0.9671 - recall_1: 0.9728 - auc_1: 0.9951 - val_loss: 0.5418 - val_binary_accuracy: 0.8228 - val_precision_1: 1.0000 - val_recall_1: 0.6780 - val_auc_1: 0.9777
# Epoch 46/70
# 67/67 [==============================] - 20s 294ms/step - loss: 0.1054 - binary_accuracy: 0.9593 - precision_1: 0.9580 - recall_1: 0.9686 - auc_1: 0.9931 - val_loss: 0.4421 - val_binary_accuracy: 0.8358 - val_precision_1: 1.0000 - val_recall_1: 0.7017 - val_auc_1: 0.9904
# Epoch 47/70
# 67/67 [==============================] - 20s 289ms/step - loss: 0.0853 - binary_accuracy: 0.9668 - precision_1: 0.9655 - recall_1: 0.9745 - auc_1: 0.9950 - val_loss: 0.4110 - val_binary_accuracy: 0.8713 - val_precision_1: 1.0000 - val_recall_1: 0.7661 - val_auc_1: 0.9879
# Epoch 48/70
# 67/67 [==============================] - 20s 287ms/step - loss: 0.1047 - binary_accuracy: 0.9565 - precision_1: 0.9601 - recall_1: 0.9610 - auc_1: 0.9931 - val_loss: 0.2185 - val_binary_accuracy: 0.9216 - val_precision_1: 1.0000 - val_recall_1: 0.8576 - val_auc_1: 0.9984
# Epoch 49/70
# 67/67 [==============================] - 20s 290ms/step - loss: 0.0550 - binary_accuracy: 0.9808 - precision_1: 0.9822 - recall_1: 0.9830 - auc_1: 0.9978 - val_loss: 0.2062 - val_binary_accuracy: 0.9235 - val_precision_1: 1.0000 - val_recall_1: 0.8610 - val_auc_1: 0.9984
# Epoch 50/70
# 67/67 [==============================] - 20s 290ms/step - loss: 0.0984 - binary_accuracy: 0.9621 - precision_1: 0.9652 - recall_1: 0.9660 - auc_1: 0.9936 - val_loss: 0.1335 - val_binary_accuracy: 0.9384 - val_precision_1: 1.0000 - val_recall_1: 0.8881 - val_auc_1: 0.9980
# Epoch 51/70
# 67/67 [==============================] - 20s 289ms/step - loss: 0.0490 - binary_accuracy: 0.9808 - precision_1: 0.9822 - recall_1: 0.9830 - auc_1: 0.9985 - val_loss: 0.3999 - val_binary_accuracy: 0.8507 - val_precision_1: 1.0000 - val_recall_1: 0.7288 - val_auc_1: 0.9908
# Epoch 52/70
# 67/67 [==============================] - 20s 288ms/step - loss: 0.0395 - binary_accuracy: 0.9860 - precision_1: 0.9881 - recall_1: 0.9864 - auc_1: 0.9985 - val_loss: 0.2971 - val_binary_accuracy: 0.9011 - val_precision_1: 1.0000 - val_recall_1: 0.8203 - val_auc_1: 0.9910
# Epoch 53/70
# 67/67 [==============================] - 20s 290ms/step - loss: 0.0402 - binary_accuracy: 0.9846 - precision_1: 0.9856 - recall_1: 0.9864 - auc_1: 0.9990 - val_loss: 0.6083 - val_binary_accuracy: 0.8078 - val_precision_1: 1.0000 - val_recall_1: 0.6508 - val_auc_1: 0.9693
# Epoch 54/70
# 67/67 [==============================] - 20s 289ms/step - loss: 0.0592 - binary_accuracy: 0.9808 - precision_1: 0.9806 - recall_1: 0.9847 - auc_1: 0.9976 - val_loss: 0.2780 - val_binary_accuracy: 0.8918 - val_precision_1: 1.0000 - val_recall_1: 0.8034 - val_auc_1: 0.9996
# Epoch 55/70
# 67/67 [==============================] - 20s 289ms/step - loss: 0.0385 - binary_accuracy: 0.9827 - precision_1: 0.9847 - recall_1: 0.9839 - auc_1: 0.9991 - val_loss: 0.2409 - val_binary_accuracy: 0.9142 - val_precision_1: 1.0000 - val_recall_1: 0.8441 - val_auc_1: 0.9980
# Epoch 56/70
# 67/67 [==============================] - 20s 289ms/step - loss: 0.0538 - binary_accuracy: 0.9780 - precision_1: 0.9780 - recall_1: 0.9822 - auc_1: 0.9982 - val_loss: 0.1092 - val_binary_accuracy: 0.9496 - val_precision_1: 1.0000 - val_recall_1: 0.9085 - val_auc_1: 0.9994
# Epoch 57/70
# 67/67 [==============================] - 20s 291ms/step - loss: 0.0554 - binary_accuracy: 0.9790 - precision_1: 0.9789 - recall_1: 0.9830 - auc_1: 0.9978 - val_loss: 0.4445 - val_binary_accuracy: 0.8190 - val_precision_1: 1.0000 - val_recall_1: 0.6712 - val_auc_1: 0.9925
# Epoch 58/70
# 67/67 [==============================] - 20s 287ms/step - loss: 0.0630 - binary_accuracy: 0.9790 - precision_1: 0.9789 - recall_1: 0.9830 - auc_1: 0.9969 - val_loss: 0.0593 - val_binary_accuracy: 0.9757 - val_precision_1: 0.9965 - val_recall_1: 0.9593 - val_auc_1: 0.9994
# Epoch 59/70
# 67/67 [==============================] - 20s 289ms/step - loss: 0.0455 - binary_accuracy: 0.9827 - precision_1: 0.9847 - recall_1: 0.9839 - auc_1: 0.9983 - val_loss: 0.1766 - val_binary_accuracy: 0.9216 - val_precision_1: 1.0000 - val_recall_1: 0.8576 - val_auc_1: 0.9997
# Epoch 60/70
# 67/67 [==============================] - 20s 289ms/step - loss: 0.0491 - binary_accuracy: 0.9836 - precision_1: 0.9856 - recall_1: 0.9847 - auc_1: 0.9981 - val_loss: 0.2081 - val_binary_accuracy: 0.9198 - val_precision_1: 1.0000 - val_recall_1: 0.8542 - val_auc_1: 0.9979
# Epoch 61/70
# 67/67 [==============================] - 20s 294ms/step - loss: 0.0393 - binary_accuracy: 0.9864 - precision_1: 0.9881 - recall_1: 0.9873 - auc_1: 0.9986 - val_loss: 0.1096 - val_binary_accuracy: 0.9571 - val_precision_1: 1.0000 - val_recall_1: 0.9220 - val_auc_1: 0.9998
# Epoch 62/70
# 67/67 [==============================] - 20s 288ms/step - loss: 0.0394 - binary_accuracy: 0.9850 - precision_1: 0.9897 - recall_1: 0.9830 - auc_1: 0.9990 - val_loss: 0.1936 - val_binary_accuracy: 0.9254 - val_precision_1: 1.0000 - val_recall_1: 0.8644 - val_auc_1: 0.9997
# Epoch 63/70
# 67/67 [==============================] - 20s 290ms/step - loss: 0.0389 - binary_accuracy: 0.9864 - precision_1: 0.9848 - recall_1: 0.9907 - auc_1: 0.9991 - val_loss: 0.2428 - val_binary_accuracy: 0.9049 - val_precision_1: 1.0000 - val_recall_1: 0.8271 - val_auc_1: 0.9964
# Epoch 64/70
# 67/67 [==============================] - 20s 289ms/step - loss: 0.0371 - binary_accuracy: 0.9864 - precision_1: 0.9856 - recall_1: 0.9898 - auc_1: 0.9988 - val_loss: 0.4599 - val_binary_accuracy: 0.8358 - val_precision_1: 1.0000 - val_recall_1: 0.7017 - val_auc_1: 0.9847
# Epoch 65/70
# 67/67 [==============================] - 20s 296ms/step - loss: 0.0420 - binary_accuracy: 0.9836 - precision_1: 0.9839 - recall_1: 0.9864 - auc_1: 0.9984 - val_loss: 0.4110 - val_binary_accuracy: 0.8507 - val_precision_1: 1.0000 - val_recall_1: 0.7288 - val_auc_1: 0.9948
# Epoch 66/70
# 67/67 [==============================] - 20s 288ms/step - loss: 0.0328 - binary_accuracy: 0.9864 - precision_1: 0.9873 - recall_1: 0.9881 - auc_1: 0.9990 - val_loss: 0.1095 - val_binary_accuracy: 0.9571 - val_precision_1: 0.9964 - val_recall_1: 0.9254 - val_auc_1: 0.9993
# Epoch 67/70
# 67/67 [==============================] - 20s 290ms/step - loss: 0.0572 - binary_accuracy: 0.9790 - precision_1: 0.9797 - recall_1: 0.9822 - auc_1: 0.9968 - val_loss: 0.1733 - val_binary_accuracy: 0.9310 - val_precision_1: 1.0000 - val_recall_1: 0.8746 - val_auc_1: 0.9981
# Epoch 68/70
# 67/67 [==============================] - 20s 290ms/step - loss: 0.0387 - binary_accuracy: 0.9832 - precision_1: 0.9847 - recall_1: 0.9847 - auc_1: 0.9991 - val_loss: 0.2306 - val_binary_accuracy: 0.9179 - val_precision_1: 1.0000 - val_recall_1: 0.8508 - val_auc_1: 0.9963
# Epoch 69/70
# 67/67 [==============================] - 21s 299ms/step - loss: 0.0220 - binary_accuracy: 0.9939 - precision_1: 0.9949 - recall_1: 0.9941 - auc_1: 0.9993 - val_loss: 0.1937 - val_binary_accuracy: 0.9347 - val_precision_1: 1.0000 - val_recall_1: 0.8814 - val_auc_1: 0.9966
# Epoch 70/70
# 67/67 [==============================] - 20s 291ms/step - loss: 0.0242 - binary_accuracy: 0.9921 - precision_1: 0.9932 - recall_1: 0.9924 - auc_1: 0.9996 - val_loss: 0.0356 - val_binary_accuracy: 0.9851 - val_precision_1: 1.0000 - val_recall_1: 0.9729 - val_auc_1: 0.9999

# %%
#output accuracy and plot figures


acc += history_fine.history['binary_accuracy']
val_acc += history_fine.history['val_binary_accuracy']

loss += history_fine.history['loss']
val_loss += history_fine.history['val_loss']




plt.figure(figsize=(12, 8))
plt.subplot(1, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.ylim([0, 1])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.plot([initial_epochs-1,initial_epochs-1],
          plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.ylim([0, 1.0])
plt.plot([initial_epochs-1,initial_epochs-1],
         plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.savefig('loss-fine-tuning.png',dpi='figure')

# %%
test2 = model.evaluate(test_set)
print('test set loss:' + str(test2[0]))
print('test set accuracy:' + str(test2[1]))
# Out:
# 6/6 [==============================] - 1s 233ms/step - loss: 0.1136 - binary_accuracy: 0.9556 - precision_1: 1.0000 - recall_1: 0.9140 - auc_1: 0.9991
# test set loss:0.11355685442686081
# test set accuracy:0.9555555582046509

# %%
model.save(os.path.join(base_dir, 'VGG19.h5'))
